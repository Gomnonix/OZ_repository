# %% [markdown]
# 컴퓨터 기초 지식을 의미하는 CS(Computer science)는<br>
# 코딩 테스트와 함께 기술 면접에서 지원자에게 필수적으로 요구합니다.<br>
#
# 수업 내용 중 기술 면접에 자주 나오는 질문 3가지와 기본적으로 알아야 할 내용 과제로 선정했습니다.<br>
#
# 관련 내용에 대해서는 구글링 또는 관련 서적을 통해 상세히 공부하시고<br>
# 답변은 최대한 핵심만 담아 간결하게 작성해주세요<br>
#
# 기술 블로그를 운영 중이신 경우<br>
# 답변 내용을 기술 블로그에 작성하신 후 링크를 답변에 남겨주셔도 됩니다.<br>

# %% [markdown]
# -----

# %% [markdown]
# [문제1]
#
# Python의 변수 할당 개념을 다른 언어와 비교해 설명해주세요

# %% [markdown]
# - java에서는 변수 앞에 자료형을 명시해야하며 이를 정적타입이라고 한다. 변수 생성과 동시에 자료형이 결정되면 이후 자료형을 변경할 수 없다.
# - Python 변수 할당은 동적 타입이므로 코드에 의해 변수의 자료형이 결정되는 동적 타입이다.

# %%
a = 1 # int type
a = "1" # str type
a = [1, 2, 3] # list type

# %% [markdown]
# ---

# %% [markdown]
# [문제2]
#
# Python의 실수형(float) 계산 시 오차가 발생하는 이유에 대해 간단히 설명해 주세요

# %% [markdown]
# - Python의 float 자료형은 64비트를 사용해 표현한다.
# 맨 앞비트는 +,-을 나타내고 이후 11비트는 정수를 나타낸다.
# 나머지 52비트가 소수를 나타낸다.
# 소수가 52비트로 정확히 표현되지 않을 때 52비트를 모두 사용하여 근사치를 이용할 수 있다.
# 그래서 정확한 값이 아닌 근사치이기에 오차가 발생할 수 있다.

# %% [markdown]
# ----

# %% [markdown]
# [문제3]
#
# 슬라이싱에 대해 간단히 설명해주세요

# %% [markdown]
# - 슬라이싱은 시퀀스 데이터 타입(list, tuple, str)의 일부를 추출하는 방법이다.
# 슬라이싱은 인덱스를 사용하여 원하는 범위의 요소를 선택하는데 유용하다.
# 일반적으로
# seq[start_index:end_index:step]으로 사용한다.

# %%
my_list = [0, 1, 2, 3, 4, 5, 6]
subset = my_list[2:7]
print(subset)
# Out:
# [2, 3, 4, 5, 6]
