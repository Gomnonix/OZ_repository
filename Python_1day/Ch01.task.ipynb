# %% [markdown]
# <span style="font-size:100%">
#
# 수업은 모두 열심히 들으셨나요?
#
# 간혹 강의에서 언급되지 않은 내용이 문제로 나올 수 있습니다.<br>
# 그럴땐 강의 내용 외 문제는 구글링을 통해 해결해주세요<br></span>
# <span style="font-size:80%">
# (구글링 또한 개발자가 갖쳐야할 역량 중에 하나랍니다 😊)
# </span>
#
# ---

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# ```인터프리트 방식에 대해 설명하고 2개 이상의 장점을 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# ▷인터프리트 방식
# - 프로그램을 실행할 때 인터프리터를 이용하여 코드를 한 줄 씩 읽어나가며 실행하는 방식으로 주로 JavaScript, Python에서 이용한다.
# ▷장점
# 1. 컴파일이라는 과정이 없기 때문에 오류에 대한 수정이 빠르다.
# 2. 번역이 빠르기 때문에 프로그램의 이식성이 좋다.

# %% [markdown]
# ---

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# ```동적 타입 방식의 장점과 단점을 간략히 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# ▷장점
# - 코드 작성 시 타입에 제한이 없기 때문에 유연성이 높고 효율적이다.
# ▷단점
# - 프로그램 실행 때 타입에 문제를 확인할 수 있기 때문에 코드가 길고 복잡할 경우
# 문제 해결이 쉽지가 않다.

# %% [markdown]
# ---

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# ```Python으로 정적타입 방식의 코드를 작성할 수 있는 방법을 구글링을 통해 검색 후 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# ▷Python의 타입 힌트
# - 파이썬 코드에 정적 타입을 선택적으로 제공하는 기능이 있다.
# - 타입 힌트가 많을수록 정적 코드 분석도구를 통해 프로그램의 잠재적 버그를 찾아낼 수 있는 정보도 많아진다.
# - typing이란 내장 모듈을 사용한다.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# <span style="font-size:80%">[문제4]<br><br></span>
# ```프로세스와 스레드의 차이점을 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# ▷프로세스
# - 프로그램을 실행시켜 정적인 프로그램이 동적으로 변하여 프로그램이 돌아가고 있는 상태를 말한다.
# - 프로그램을 메모리에 할당하고 CPU 자원을 할당 받아 프로그램이 실행되고 있는 상태
# ![image.png](attachment:image.png)
#
# ▷스레드
# - 프로세스 내의 더 가벼운 공유 메모리 단위로 작업의 효율적인 병렬 실행을 가능하게 하고 프로세스의 하위 집합이며 경량 프로세스라고도 한다.
# - 프로세스 내에서 동시에 진행되는 작업 갈래, 흐름의 단위
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ---

# %% [markdown]
# <span style="font-size:80%">[문제5]<br><br></span>
# ```Python 2버전대와 3버전대의 차이를 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# - Python3 에서는 기본적으로 문자열은 Unicode이고 Python2에서는 기본적으로
# 문자열은 ASCII이다 그래서 Unicode시에는 “u”를 붙여야 한다.
# - Python3의 정수 처리 기능이 개선되었다. Python2 경우는 실수형태를 입력을 해줘야
# 했지만 Python3는 입력하는 그대로의 결과가 나온다.
# - Python3는 print문에 괄호()가 필수적으로 들어가야만 출력이 된다.
# - Python3 새로운 오류 유형이 도입되었다.
# - 텍스트 오브젝트 데이터 유형은 Python2와 Python3에서 다르게 작동한다.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# <span style="font-size:80%">[문제6]<br><br></span>
# ```Python에서 메모리 관리는 어떻게 이루어지는지 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# Python은 자동으로 메모리를 관리하는 고급 프로그래밍언어이다.
# Python의 메모리 관리는 참조 계수 referencecounting 기반으로 이루어진다.
# 이는 객체가 생성될 때마다 그 객체를 참조하는 변수의 개수를 추적하는 방식이다.
# 객체의 변수의 개수가 0이되면, 해당 객체의 메모리는 자동으로 해제된다.
